# %% [markdown]
# > Data Report Experimento 1:
# * R2 Score:  -0.9707202172050842
# * MSE:  402.436875888414
# * RMSE:  20.06082939183757

# %% [markdown]
# > Data Report Experimento 2 (Com dados gerados):
# * R2 Score: -0.452627847746891
# * MSE: 0.6183337968401122
# * RMSE: 0.7863420355291406
