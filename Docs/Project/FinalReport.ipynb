# %% [markdown]
# # Final Report

# %% [markdown]
# ## Desafios

# %% [markdown]
# * Dataset bem curto apenas 4 meses de dados, tornando dificil o treinamento.

# %% [markdown]
# ## Ações a serem realizadas

# %% [markdown]
# * Corrigir/melhorar dataset.
# * Desligar ou ligar o ar de acordo com a data do modelo preditivo.
